# %% [markdown]
# # Module 02: Working with Time Series Data
#
# https://www.hydroshare.org/resource/aafcc55f646b4207ae975490e6f752ab/
# https://www.hydroshare.org/resource/757ed05854ab430dae99841f44622283/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

resource_id = '757ed05854ab430dae99841f44622283'
WY = 2017

# File name format = WY_YYYY_UpMetS_soil_snow_daily.csv

# %%
file_base = 'WY_'+str(WY)+'_UpMetS_soil_snow_daily.csv'

csv_file = '~/downloads/'+resource_id+'/'+resource_id+'/data/contents/'+file_base

df = pd.read_csv(csv_file)
df
# Out:
#       date_time  Year  Month  Day  DOY  decimal_year  water_year  WYD  \
# 0    2016-10-01  2016     10    1  275      0.748634        2017    1
# 1    2016-10-02  2016     10    2  276      0.751366        2017    2
# 2    2016-10-03  2016     10    3  277      0.754098        2017    3
# 3    2016-10-04  2016     10    4  278      0.756831        2017    4
# 4    2016-10-05  2016     10    5  279      0.759563        2017    5
# ..          ...   ...    ...  ...  ...           ...         ...  ...
# 361  2017-09-27  2017      9   27  270      0.736986        2017  362
# 362  2017-09-28  2017      9   28  271      0.739726        2017  363
# 363  2017-09-29  2017      9   29  272      0.742466        2017  364
# 364  2017-09-30  2017      9   30  273      0.745205        2017  365
# 365  2017-10-01  2017     10    1  274      0.747945        2018    1
#
#      decimal_water_year  VWC_acde10  ...  air_temp_acuc(Deg C)_min  \
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# date_time
# Year
# Month
# Day
# DOY
# decimal_year
# water_year
# WYD
# decimal_water_year
# VWC_acde10
# VWC_acde10_max
# VWC_acde10_min
# VWC_acuc10
# VWC_acuc10_max
# VWC_acuc10_min
# VWC_open10
# VWC_open10_max
# VWC_open10_min
# VWC_qkde10
# VWC_qkde10_max
# VWC_qkde10_min
# VWC_qkuc10
# VWC_qkuc10_max
# VWC_qkuc10_min
# VWC_acde30
# VWC_acde30_max
# VWC_acde30_min
# VWC_acuc30
# VWC_acuc30_max
# VWC_acuc30_min
# VWC_open30
# VWC_open30_max
# VWC_open30_min
# VWC_qkde30
# VWC_qkde30_max
# VWC_qkde30_min
# VWC_qkuc30
# VWC_qkuc30_max
# VWC_qkuc30_min
# VWC_acde60
# VWC_acde60_max
# VWC_acde60_min
# VWC_acuc60
# VWC_acuc60_max
# VWC_acuc60_min
# VWC_open60
# VWC_open60_max
# VWC_open60_min
# VWC_qkde60
# VWC_qkde60_max
# VWC_qkde60_min
# VWC_qkuc60
# VWC_qkuc60_max
# VWC_qkuc60_min
# VWC_qkuc90
# VWC_qkuc90_max
# VWC_qkuc90_min
# soil_temp_acde10(Deg C)
# soil_temp_acde10(Deg C)_max
# soil_temp_acde10(Deg C)_min
# soil_temp_acuc10(Deg C)
# soil_temp_acuc10(Deg C)_max
# ...

# %%
df['VWC_acde10'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # TODOs
#
# 1. Compute daily averages
# 2. Compute seasonal cycles for N- and S-facing
# 3. Plot for N- and S-facing
